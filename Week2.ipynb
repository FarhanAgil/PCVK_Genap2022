# %% [markdown]
# <a href="https://colab.research.google.com/github/FarhanAgil/PCVK_Genap2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#akses gdrive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi ke rbg
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap = 'magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file
#cv.imwrite('/content/drive/MyDrive/PCVK/Images/kitten01.jpg', img5)

#tampilkan plot dengan ukuran canvas lebih besar
fig = plt.figure(figsize=(10,10))   #ubah ukuran sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
from numpy.lib.function_base import blackman
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=8)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='HELLO',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) 
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#1
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
#2
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %%
#3
plt.imshow(img[5:30])

# %%
#4
img_ktk = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_ktk, pt1=(300,300), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img_ktk, pt1=(400,150), pt2=(350,400), color=(0,255,0),thickness=10)
cv.rectangle(img_ktk, pt1=(550,200), pt2=(650,300), color=(255,255,255),thickness=10)
cv.rectangle(img_ktk, pt1=(100,600), pt2=(200,400), color=(255,0,0),thickness=10)
cv.rectangle(img_ktk, pt1=(550,300), pt2=(300,450), color=(0,0,255),thickness=10)
plt.imshow(img_ktk)

# %%
#5
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %%
img_6 = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg')
plt.imshow(img_6)


cv.rectangle(img_6,pt1=(220,20),pt2=(550,300),color=(255,0,255),thickness=10)
plt.imshow(img_6)


cv.circle(img_6, center=(380,170),radius=130,color=(0,0,0),thickness=10)
plt.imshow(img_6)

# %%
img_7 = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg')
plt.imshow(img_7)


img_rgb = cv.cvtColor(img_7,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)


cv.rectangle(img_rgb,pt1=(150,500),pt2=(15,600),color=(0,0,255),thickness=10)
plt.imshow(img_rgb)
